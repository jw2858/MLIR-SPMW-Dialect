# %% [markdown]
# # CIRCT Object File Symbol Analysis
#
# This notebook analyzes the defined and undefined symbols in CIRCT's object (`.o`) files to understand symbol resolution, identify potential linkage issues, and visualize inter-object-file dependencies.
#
# We:
# - Load symbol tables for all `.o` files
# - Analyze which symbols are defined or undefined where
# - Build graphs of object-file dependencies
# - Identify any undefined (unresolved) symbols not provided in this build tree

# %%
import json

# %%
import sys

# %%
from collections import Counter

# %%
import networkx as nx

# %% [markdown]
# ## Load Symbol Information
#
# We begin by loading a JSON file that maps each object file to its defined (`T`) and undefined (`U`) symbols (as output by tools like `nm`).

# %%
with open('symbols-in-o-files.json', 'r') as f:
    symbols_in_o_files = json.load(f)

# %% [markdown]
# ## Symbol Types Found
#
# We find the following symbol types in the dataset:
#
# - `T`, `t`: Functions or variables defined in this object file (uppercase = global, lowercase = local)
# - `U`: Undefined symbols
# - (Other types seen: `B`, `D`, `R`, `V`, `W`, `b`, `d`, `r`)
#
# In this notebook, our focus is primarily on `T` (definitions) and `U` (unresolved references).

# %%
all_symbol_types = set()
for o_file, symbol_types_to_symbols in symbols_in_o_files.items():
    all_symbol_types.update(symbol_types_to_symbols)
all_symbol_types
# Out:
# {'B', 'D', 'R', 'T', 'U', 'V', 'W', 'b', 'd', 'n', 'r', 't', 'w'}

# %% [markdown]
# ## Defined Symbols Analysis
#
# We map all globally defined symbols (type `T`) to the list of object files that define them. Each symbol should ideally be defined once; multiple definitions suggest possible ODR (One Definition Rule) violations or, more commonly, separate "main" functions for different tools.

# %%
t_symbols_to_o_files = {}
for o_file, symbol_types_to_symbols in symbols_in_o_files.items():
    for symbol_type, symbols in symbol_types_to_symbols.items():
        if symbol_type.isupper() and symbol_type != 'U':
            for symbol in symbols:
                t_symbols_to_o_files.setdefault(symbol, []).append(o_file)

# %%
len(t_symbols_to_o_files)
# Out:
# 836842

# %%
Counter(len(o_files) for o_files in t_symbols_to_o_files.values())
# Out:
# Counter({1: 737151,
#          2: 41639,
#          3: 16825,
#          4: 9177,
#          5: 5905,
#          6: 3998,
#          8: 2280,
#          7: 2129,
#          9: 2006,
#          10: 1459,
#          12: 1184,
#          11: 1167,
#          13: 925,
#          15: 581,
#          14: 570,
#          17: 507,
#          20: 424,
#          18: 420,
#          32: 405,
#          24: 351,
#          19: 343,
#          16: 322,
#          21: 296,
#          28: 270,
#          23: 263,
#          25: 261,
#          26: 258,
#          27: 249,
#          22: 238,
#          41: 212,
#          29: 194,
#          72: 140,
#          31: 129,
#          40: 119,
#          30: 116,
#          47: 113,
#          33: 108,
#          61: 98,
#          42: 92,
#          46: 89,
#          87: 89,
#          35: 84,
#          58: 82,
#          69: 82,
#          39: 79,
#          43: 79,
#          45: 79,
#          44: 78,
#          34: 74,
#          37: 74,
#          49: 73,
#          66: 72,
#          80: 72,
#          294: 66,
#          57: 65,
#          54: 63,
#          38: 60,
#          86: 56,
#          94: 55,
#          48: 55,
#          36: 54,
#          279: 53,
#          515: 52,
#          65: 52,
#          289: 51,
#          90: 46,
#          59: 45,
#          53: 44,
#          50: 43,
#          56: 40,
#          62: 39,
#          55: 38,
#          52: 37,
#          117: 35,
#          60: 35,
#          113: 33,
#          507: 33,
#          85: 33,
#          115: 32,
#          51: 30,
#          73: 29,
#          74: 28,
#          67: 28,
#          68: 27,
#          99: 27,
#          108: 27,
#          77: 26,
#          112: 26,
#          64: 25,
#          79: 25,
#          230: 25,
#          70: 24,
#          83: 23,
#          92: 22,
#          89: 22,
#          88: 22,
#          71: 21,
#          76: 21,
#          156: 19,
#          438: 19,
#          127: 19,
#          97: 19,
#          63: 19,
#          102: 18,
#          231: 18,
#          82: 18,
#          98: 17,
#          182: 16,
#          101: 16,
#          165: 16,
#          84: 15,
#          180: 14,
#          139: 14,
#          95: 14,
#          121: 14,
#          78: 13,
#          75: 13,
#          168: 13,
#          96: 12,
#          141: 12,
#          120: 11,
#          118: 11,
#          526: 10,
#          281: 10,
#          105: 10,
#          81: 10,
#          91: 10,
#          93: 10,
#          116: 10,
#          106: 9,
#          104: 9,
#          181: 9,
#          143: 9,
#          114: 8,
#          136: 8,
#          110: 8,
#          107: 8,
#          137: 8,
#          174: 8,
#          258: 8,
#          157: 8,
#          119: 7,
#          440: 7,
#          125: 7,
#          490: 7,
#          226: 7,
#          163: 7,
#          153: 7,
#          135: 7,
#          100: 7,
#          159: 7,
#          122: 7,
#          192: 6,
#          328: 6,
#          244: 6,
#          109: 6,
#          176: 6,
#          172: 6,
#          178: 6,
#          189: 6,
#          169: 6,
#          240: 6,
#          255: 6,
#          123: 6,
#          124: 6,
#          464: 5,
#          140: 5,
#          151: 5,
#          103: 5,
#          219: 5,
#          529: 5,
#          217: 5,
#          152: 5,
#          150: 5,
#          208: 5,
#          388: 5,
#          224: 5,
#          145: 5,
#          354: 4,
#          130: 4,
#          1717: 4,
#          138: 4,
#          436: 4,
#          202: 4,
#          530: 4,
#          256: 4,
#          283: 4,
#          128: 4,
#          245: 4,
#          216: 4,
#          132: 4,
#          183: 4,
#          206: 4,
#          195: 4,
#          194: 4,
#          126: 4,
#          146: 4,
#          212: 3,
#          332: 3,
#          266: 3,
#          160: 3,
#          291: 3,
#          433: 3,
#          509: 3,
#          269: 3,
#          280: 3,
#          508: 3,
#          242: 3,
#          446: 3,
#          215: 3,
#          353: 3,
#          173: 3,
#          241: 3,
#          257: 3,
#          233: 3,
#          307: 3,
#          144: 3,
#          129: 3,
#          317: 3,
#          261: 3,
#          167: 3,
#          250: 3,
#          111: 3,
#          316: 3,
#          220: 3,
#          155: 3,
#          197: 3,
#          199: 3,
#          248: 3,
#          331: 3,
#          671: 2,
#          318: 2,
#          400: 2,
#          274: 2,
#          287: 2,
#          412: 2,
#          406: 2,
#          247: 2,
#          336: 2,
#          481: 2,
#          532: 2,
#          267: 2,
#          211: 2,
#          259: 2,
#          489: 2,
#          263: 2,
#          513: 2,
#          510: 2,
#          363: 2,
#          305: 2,
#          372: 2,
#          488: 2,
#          1755: 2,
#          282: 2,
#          177: 2,
#          452: 2,
#          171: 2,
#          166: 2,
#          179: 2,
#          618: 2,
#          246: 2,
#          432: 2,
#          210: 2,
#          222: 2,
#          154: 2,
#          239: 2,
#          175: 2,
#          188: 2,
#          187: 2,
#          149: 2,
#          285: 2,
#          297: 2,
#          262: 2,
#          201: 2,
#          326: 2,
#          522: 1,
#          1244: 1,
#          260: 1,
#          466: 1,
#          435: 1,
#          304: 1,
#          131: 1,
#          333: 1,
#          299: 1,
#          325: 1,
#          343: 1,
#          528: 1,
#          492: 1,
#          410: 1,
#          469: 1,
#          1532: 1,
#          527: 1,
#          511: 1,
#          237: 1,
#          431: 1,
#          437: 1,
#          374: 1,
#          425: 1,
#          344: 1,
#          347: 1,
#          313: 1,
#          468: 1,
#          362: 1,
#          1676: 1,
#          429: 1,
#          427: 1,
#          443: 1,
#          487: 1,
#          382: 1,
#          381: 1,
#          531: 1,
#          453: 1,
#          473: 1,
#          4162: 1,
#          486: 1,
#          478: 1,
#          162: 1,
#          207: 1,
#          723: 1,
#          227: 1,
#          229: 1,
#          409: 1,
#          292: 1,
#          133: 1,
#          327: 1,
#          296: 1,
#          223: 1,
#          396: 1,
#          312: 1,
#          360: 1,
#          686: 1,
#          286: 1,
#          691: 1,
#          290: 1,
#          367: 1,
#          357: 1,
#          398: 1,
#          273: 1,
#          147: 1,
#          198: 1,
#          196: 1,
#          254: 1,
#          253: 1,
#          243: 1,
#          249: 1,
#          329: 1,
#          288: 1,
#          134: 1,
#          161: 1,
#          272: 1,
#          300: 1,
#          204: 1,
#          203: 1,
#          205: 1,
#          277: 1,
#          218: 1,
#          235: 1,
#          390: 1,
#          415: 1,
#          186: 1,
#          228: 1,
#          142: 1,
#          2038: 1,
#          1672: 1,
#          1202: 1,
#          777: 1,
#          395: 1,
#          501: 1,
#          384: 1})

# %% [markdown]
# **Observation:**
# Most symbols are uniquely defined (which is expected).

# %% [markdown]
# ## Undefined Symbols Analysis
#
# We then map each undefined symbol (type `U`) to the list of object files that use (need) it. These symbols are those which this set of object files expects to be provided elsewhere—either by other object files, by static/dynamic libraries, or by the runtime.

# %%
u_symbols_to_o_files = {}
for o_file, symbol_types_to_symbols in symbols_in_o_files.items():
    for u_symbol in symbol_types_to_symbols.get('U', ()):
        u_symbols_to_o_files.setdefault(u_symbol, []).append(o_file)

# %%
len(u_symbols_to_o_files)
# Out:
# 62553

# %%
Counter(
    len(t_symbols_to_o_files.get(u_symbol, []))
    for u_symbol in u_symbols_to_o_files
)
# Out:
# Counter({1: 61893,
#          0: 614,
#          6: 32,
#          2: 3,
#          5: 3,
#          3: 2,
#          11: 1,
#          19: 1,
#          7: 1,
#          4: 1,
#          244: 1,
#          255: 1})

# %%
sorted(
    u_symbol
    for u_symbol in u_symbols_to_o_files
    if u_symbol not in t_symbols_to_o_files
)
# Out:
# ['ZSTD_CCtx_setParameter',
#  'ZSTD_compress2',
#  'ZSTD_compressBound',
#  'ZSTD_createCCtx',
#  'ZSTD_decompress',
#  'ZSTD_freeCCtx',
#  'ZSTD_getErrorName',
#  'ZSTD_isError',
#  '_Exit',
#  '_Unwind_Backtrace',
#  '_Unwind_GetIP',
#  '_Unwind_Resume',
#  '_ZN5circt13importVerilogERN4llvm9SourceMgrEPN4mlir11MLIRContextERNS3_11TimingScopeENS3_8ModuleOpEPKNS_20ImportVerilogOptionsE',
#  '_ZN5circt15getSlangVersionEv',
#  '_ZN5circt17preprocessVerilogERN4llvm9SourceMgrEPN4mlir11MLIRContextERNS3_11TimingScopeERNS0_11raw_ostreamEPKNS_20ImportVerilogOptionsE',
#  '_ZN5circt26populateLlhdToCorePipelineERN4mlir13OpPassManagerERKNS_25LlhdToCorePipelineOptionsE',
#  '_ZN5circt27populateMooreToCorePipelineERN4mlir13OpPassManagerE',
#  '_ZN5circt30populateVerilogToMoorePipelineERN4mlir13OpPassManagerE',
#  '_ZN5circt3lsp13VerilogServer11addDocumentERKN4llvm3lsp10URIForFileENS2_9StringRefElRNSt3__16vectorINS3_10DiagnosticENS8_9allocatorISA_EEEE',
#  '_ZN5circt3lsp13VerilogServer14getLocationsOfERKN4llvm3lsp10URIForFileERKNS3_8PositionERNSt3__16vectorINS3_8LocationENSA_9allocatorISC_EEEE',
#  '_ZN5circt3lsp13VerilogServer14removeDocumentERKN4llvm3lsp10URIForFileE',
#  '_ZN5circt3lsp13VerilogServer14updateDocumentERKN4llvm3lsp10URIForFileENS2_8ArrayRefINS3_30TextDocumentContentChangeEventEEElRNSt3__16vectorINS3_10DiagnosticENSA_9allocatorISC_EEEE',
#  '_ZN5circt3lsp13VerilogServer16findReferencesOfERKN4llvm3lsp10URIForFileERKNS3_8PositionERNSt3__16vectorINS3_8LocationENSA_9allocatorISC_EEEE',
#  '_ZN5circt3lsp13VerilogServerC1ERKNS0_20VerilogServerOptionsE',
#  '_ZN5circt3lsp13VerilogServerD1Ev',
#  '_ZNKSt3__110error_code7messageEv',
#  '_ZNKSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE4findEcm',
#  '_ZNKSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE5rfindEcm',
#  '_ZNKSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE7compareEmmPKcm',
#  '_ZNKSt3__114error_category10equivalentERKNS_10error_codeEi',
#  '_ZNKSt3__114error_category10equivalentEiRKNS_15error_conditionE',
#  '_ZNKSt3__114error_category23default_error_conditionEi',
#  '_ZNKSt3__115basic_stringbufIcNS_11char_traitsIcEENS_9allocatorIcEEE3strEv',
#  '_ZNKSt3__119__shared_weak_count13__get_deleterERKSt9type_info',
#  '_ZNKSt3__123__match_any_but_newlineIcE6__execERNS_7__stateIcEE',
#  '_ZNKSt3__14__fs10filesystem4path10__filenameEv',
#  '_ZNKSt3__14__fs10filesystem4path11__extensionEv',
#  '_ZNKSt3__14__fs10filesystem4path13__parent_pathEv',
#  '_ZNKSt3__14__fs10filesystem4path16__root_directoryEv',
#  '_ZNKSt3__16locale4nameEv',
#  '_ZNKSt3__16locale9use_facetERNS0_2idE',
#  '_ZNKSt3__18ios_base6getlocEv',
#  '_ZNSt11logic_errorC2EPKc',
#  '_ZNSt12length_errorD1Ev',
#  '_ZNSt12out_of_rangeD1Ev',
#  '_ZNSt13exception_ptrC1ERKS_',
#  '_ZNSt13exception_ptrD1Ev',
#  '_ZNSt19bad_optional_accessD1Ev',
#  '_ZNSt20bad_array_new_lengthC1Ev',
#  '_ZNSt20bad_array_new_lengthD1Ev',
#  '_ZNSt3__111__call_onceERVmPvPFvS2_E',
#  '_ZNSt3__111regex_errorC1ENS_15regex_constants10error_typeE',
#  '_ZNSt3__111regex_errorD1Ev',
#  '_ZNSt3__111this_thread9sleep_forERKNS_6chrono8durationIxNS_5ratioILl1ELl1000000000EEEEE',
#  '_ZNSt3__112__next_primeEm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE5eraseEmm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6__initEPKcm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6__initEmc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6appendEPKc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6appendEPKcm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6appendEmc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6assignEPKc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6assignEPKcm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6insertENS_11__wrap_iterIPKcEEc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6insertEmPKc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6insertEmPKcm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6insertEmmc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6resizeEmc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE7replaceEmmPKc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE7replaceEmmPKcm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE7reserveEm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE9__grow_byEmmmmmm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE9push_backEc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEC1ERKS5_',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEC1ERKS5_mmRKS4_',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEED1Ev',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEED2Ev',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEaSERKS5_',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEaSEc',
#  '_ZNSt3__112basic_stringIwNS_11char_traitsIwEENS_9allocatorIwEEE6resizeEmw',
#  '_ZNSt3__112future_errorC1ENS_10error_codeE',
#  '_ZNSt3__112placeholders2_1E',
#  '_ZNSt3__113__hash_memoryEPKvm',
#  '_ZNSt3__113basic_filebufIcNS_11char_traitsIcEEE4openEPKcj',
#  '_ZNSt3__113basic_filebufIcNS_11char_traitsIcEEE5closeEv',
#  '_ZNSt3__113basic_filebufIcNS_11char_traitsIcEEEC1Ev',
#  '_ZNSt3__113basic_filebufIcNS_11char_traitsIcEEED1Ev',
#  '_ZNSt3__113basic_istreamIcNS_11char_traitsIcEEE6sentryC1ERS3_b',
#  '_ZNSt3__113basic_istreamIcNS_11char_traitsIcEEED2Ev',
#  '_ZNSt3__113basic_istreamIcNS_11char_traitsIcEEErsERd',
#  '_ZNSt3__113basic_istreamIcNS_11char_traitsIcEEErsERf',
#  '_ZNSt3__113basic_istreamIcNS_11char_traitsIcEEErsERi',
#  '_ZNSt3__113basic_istreamIcNS_11char_traitsIcEEErsERl',
#  '_ZNSt3__113basic_istreamIcNS_11char_traitsIcEEErsERm',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEE3putEc',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEE5flushEv',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEE5writeEPKcl',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEE6sentryC1ERS3_',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEE6sentryD1Ev',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEED2Ev',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEElsEPKv',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEElsEb',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEElsEd',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEElsEf',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEElsEi',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEElsEj',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEElsEl',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEElsEm',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEElsEs',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEElsEt',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEElsEy',
#  '_ZNSt3__113random_deviceC2ERKNS_12basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEE',
#  '_ZNSt3__113random_deviceD1Ev',
#  '_ZNSt3__113random_deviceclEv',
#  '_ZNSt3__113shared_futureIvED1Ev',
#  '_ZNSt3__114__shared_countD2Ev',
#  '_ZNSt3__114basic_iostreamIcNS_11char_traitsIcEEED2Ev',
#  '_ZNSt3__114basic_ofstreamIcNS_11char_traitsIcEEE4openEPKcj',
#  '_ZNSt3__114basic_ofstreamIcNS_11char_traitsIcEEE4openERKNS_12basic_stringIcS2_NS_9allocatorIcEEEEj',
#  '_ZNSt3__114error_categoryD2Ev',
#  '_ZNSt3__115__get_classnameEPKcb',
#  '_ZNSt3__115__thread_structC1Ev',
#  '_ZNSt3__115__thread_structD1Ev',
#  '_ZNSt3__115basic_streambufIcNS_11char_traitsIcEEEC2Ev',
#  '_ZNSt3__115basic_streambufIcNS_11char_traitsIcEEED2Ev',
#  '_ZNSt3__115basic_stringbufIcNS_11char_traitsIcEENS_9allocatorIcEEE3strERKNS_12basic_stringIcS2_S4_EE',
#  '_ZNSt3__115future_categoryEv',
#  '_ZNSt3__115recursive_mutex4lockEv',
#  '_ZNSt3__115recursive_mutex6unlockEv',
#  '_ZNSt3__115recursive_mutexC1Ev',
#  '_ZNSt3__115recursive_mutexD1Ev',
#  '_ZNSt3__115system_categoryEv',
#  '_ZNSt3__116generic_categoryEv',
#  '_ZNSt3__117__assoc_sub_state10__sub_waitERNS_11unique_lockINS_5mutexEEE',
#  '_ZNSt3__117__assoc_sub_state12__make_readyEv',
#  '_ZNSt3__117__assoc_sub_state13set_exceptionESt13exception_ptr',
#  '_ZNSt3__117__assoc_sub_state16__on_zero_sharedEv',
#  '_ZNSt3__117__assoc_sub_state4waitEv',
#  '_ZNSt3__117__assoc_sub_state9__executeEv',
#  '_ZNSt3__117__assoc_sub_state9set_valueEv',
#  '_ZNSt3__117bad_function_callD1Ev',
#  '_ZNSt3__118condition_variable10notify_allEv',
#  '_ZNSt3__118condition_variable10notify_oneEv',
#  '_ZNSt3__118condition_variable4waitERNS_11unique_lockINS_5mutexEEE',
#  '_ZNSt3__118condition_variableD1Ev',
#  '_ZNSt3__119__shared_mutex_base11lock_sharedEv',
#  '_ZNSt3__119__shared_mutex_base13unlock_sharedEv',
#  '_ZNSt3__119__shared_mutex_base4lockEv',
#  '_ZNSt3__119__shared_mutex_base6unlockEv',
#  '_ZNSt3__119__shared_mutex_baseC1Ev',
#  '_ZNSt3__119__shared_weak_count14__release_weakEv',
#  '_ZNSt3__119__shared_weak_count4lockEv',
#  '_ZNSt3__119__shared_weak_countD2Ev',
#  '_ZNSt3__119__thread_local_dataEv',
#  '_ZNSt3__120__get_collation_nameEPKc',
#  '_ZNSt3__120__throw_system_errorEiPKc',
#  '_ZNSt3__122__libcpp_verbose_abortEPKcz',
#  '_ZNSt3__13cinE',
#  '_ZNSt3__14__fs10filesystem14__current_pathEPNS_10error_codeE',
#  '_ZNSt3__14cerrE',
#  '_ZNSt3__14clogE',
#  '_ZNSt3__14coutE',
#  '_ZNSt3__14stodERKNS_12basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEEPm',
#  '_ZNSt3__14stofERKNS_12basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEEPm',
#  '_ZNSt3__14stolERKNS_12basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEEPmi',
#  '_ZNSt3__15ctypeIcE2idE',
#  '_ZNSt3__15mutex4lockEv',
#  '_ZNSt3__15mutex6unlockEv',
#  '_ZNSt3__15mutex8try_lockEv',
#  '_ZNSt3__15stoulERKNS_12basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEEPmi',
#  '_ZNSt3__16__sortIRNS_6__lessIccEEPcEEvT0_S5_T_',
#  '_ZNSt3__16__sortIRNS_6__lessIddEEPdEEvT0_S5_T_',
#  '_ZNSt3__16__sortIRNS_6__lessIffEEPfEEvT0_S5_T_',
#  '_ZNSt3__16__sortIRNS_6__lessIiiEEPiEEvT0_S5_T_',
#  '_ZNSt3__16__sortIRNS_6__lessIjjEEPjEEvT0_S5_T_',
#  '_ZNSt3__16__sortIRNS_6__lessIllEEPlEEvT0_S5_T_',
#  '_ZNSt3__16__sortIRNS_6__lessImmEEPmEEvT0_S5_T_',
#  '_ZNSt3__16__sortIRNS_6__lessIttEEPtEEvT0_S5_T_',
#  '_ZNSt3__16chrono12steady_clock3nowEv',
#  '_ZNSt3__16chrono12system_clock11from_time_tEl',
#  '_ZNSt3__16chrono12system_clock3nowEv',
#  '_ZNSt3__16chrono12system_clock9to_time_tERKNS0_10time_pointIS1_NS0_8durationIxNS_5ratioILl1ELl1000000EEEEEEE',
#  '_ZNSt3__16futureIvEC1EPNS_17__assoc_sub_stateE',
#  '_ZNSt3__16futureIvED1Ev',
#  '_ZNSt3__16locale7classicEv',
#  '_ZNSt3__16localeC1ERKS0_',
#  '_ZNSt3__16localeC1Ev',
#  '_ZNSt3__16localeD1Ev',
#  '_ZNSt3__16localeaSERKS0_',
#  '_ZNSt3__16thread20hardware_concurrencyEv',
#  '_ZNSt3__16thread4joinEv',
#  '_ZNSt3__16thread6detachEv',
#  '_ZNSt3__16threadD1Ev',
#  '_ZNSt3__17collateIcE2idE',
#  '_ZNSt3__17promiseIvE10get_futureEv',
#  '_ZNSt3__17promiseIvE9set_valueEv',
#  '_ZNSt3__17promiseIvEC1Ev',
#  '_ZNSt3__17promiseIvED1Ev',
#  '_ZNSt3__18ios_base33__set_badbit_and_consider_rethrowEv',
#  '_ZNSt3__18ios_base4InitC1Ev',
#  '_ZNSt3__18ios_base4InitD1Ev',
#  '_ZNSt3__18ios_base4initEPv',
#  '_ZNSt3__18ios_base5clearEj',
#  '_ZNSt3__18ios_base5imbueERKNS_6localeE',
#  '_ZNSt3__19basic_iosIcNS_11char_traitsIcEEED2Ev',
#  '_ZNSt3__19to_stringEd',
#  '_ZNSt3__19to_stringEf',
#  '_ZNSt3__19to_stringEi',
#  '_ZNSt3__19to_stringEj',
#  '_ZNSt3__19to_stringEl',
#  '_ZNSt3__19to_stringEm',
#  '_ZNSt3__19to_stringEy',
#  '_ZNSt3__1plIcNS_11char_traitsIcEENS_9allocatorIcEEEENS_12basic_stringIT_T0_T1_EEPKS6_RKS9_',
#  '_ZNSt9exceptionD2Ev',
#  '_ZSt15set_new_handlerPFvvE',
#  '_ZSt17current_exceptionv',
#  '_ZSt17rethrow_exceptionSt13exception_ptr',
#  '_ZSt7nothrow',
#  '_ZSt9terminatev',
#  '_ZTINSt3__119__shared_weak_countE',
#  '_ZTTNSt3__114basic_ifstreamIcNS_11char_traitsIcEEEE',
#  '_ZTTNSt3__114basic_ofstreamIcNS_11char_traitsIcEEEE',
#  '_ZTTNSt3__118basic_stringstreamIcNS_11char_traitsIcEENS_9allocatorIcEEEE',
#  '_ZTTNSt3__119basic_istringstreamIcNS_11char_traitsIcEENS_9allocatorIcEEEE',
#  '_ZTTNSt3__119basic_ostringstreamIcNS_11char_traitsIcEENS_9allocatorIcEEEE',
#  '_ZTVN10__cxxabiv117__class_type_infoE',
#  '_ZTVN10__cxxabiv120__si_class_type_infoE',
#  '_ZTVN10__cxxabiv121__vmi_class_type_infoE',
#  '_ZTVNSt3__114__shared_countE',
#  '_ZTVNSt3__114basic_ifstreamIcNS_11char_traitsIcEEEE',
#  '_ZTVNSt3__114basic_ofstreamIcNS_11char_traitsIcEEEE',
#  '_ZTVNSt3__115basic_streambufIcNS_11char_traitsIcEEEE',
#  '_ZTVNSt3__115basic_stringbufIcNS_11char_traitsIcEENS_9allocatorIcEEEE',
#  '_ZTVNSt3__117__assoc_sub_stateE',
#  '_ZTVNSt3__117bad_function_callE',
#  '_ZTVNSt3__118basic_stringstreamIcNS_11char_traitsIcEENS_9allocatorIcEEEE',
#  '_ZTVNSt3__119__shared_weak_countE',
#  '_ZTVNSt3__119basic_istringstreamIcNS_11char_traitsIcEENS_9allocatorIcEEEE',
#  '_ZTVNSt3__119basic_ostringstreamIcNS_11char_traitsIcEENS_9allocatorIcEEEE',
#  '_ZTVNSt3__18ios_baseE',
#  '_ZTVNSt3__19basic_iosIcNS_11char_traitsIcEEEE',
#  '_ZTVSt12length_error',
#  '_ZTVSt12out_of_range',
#  '_ZTVSt18bad_variant_access',
#  '_ZTVSt19bad_optional_access',
#  '_ZTVSt9exception',
#  '_ZdaPv',
#  '_ZdaPvm',
#  '_ZdlPv',
#  '_ZdlPvSt11align_val_t',
#  '_ZdlPvm',
#  '_ZdlPvmSt11align_val_t',
#  '_Znam',
#  '_Znwm',
#  '_ZnwmRKSt9nothrow_t',
#  '_ZnwmSt11align_val_t',
#  '_ZnwmSt11align_val_tRKSt9nothrow_t',
#  '__assert_fail',
#  '__ctype_b_loc',
#  '__ctype_tolower_loc',
#  '__ctype_toupper_loc',
#  '__cxa_allocate_exception',
#  '__cxa_atexit',
#  '__cxa_begin_catch',
#  '__cxa_end_catch',
#  '__cxa_free_exception',
#  '__cxa_guard_abort',
#  '__cxa_guard_acquire',
#  '__cxa_guard_release',
#  '__cxa_pure_virtual',
#  '__cxa_rethrow',
#  '__cxa_thread_atexit',
#  '__cxa_throw',
#  '__deregister_frame',
#  '__dso_handle',
#  '__errno_location',
#  '__gxx_personality_v0',
#  '__isoc23_fscanf',
#  '__isoc23_scanf',
#  '__isoc23_sscanf',
#  '__isoc23_strtol',
#  '__isoc23_strtoll',
#  '__isoc23_strtoul',
#  '__isoc23_strtoull',
#  '__register_frame',
#  '__rseq_offset',
#  '__rseq_size',
#  '__sched_cpucount',
#  '__tls_get_addr',
#  '_exit',
#  '_setjmp',
#  'abort',
#  'accept',
#  'access',
#  'acos',
#  'acosf',
#  'acosh',
#  'acoshf',
#  'alarm',
#  'aligned_alloc',
#  'arc4random',
#  'asin',
#  'asinf',
#  'asinh',
#  'asinhf',
#  'atan',
#  'atan2',
#  'atan2f',
#  'atanf',
#  'atanh',
#  'atanhf',
#  'atexit',
#  'backtrace',
#  'bcmp',
#  'bind',
#  'calloc',
#  'ceil',
#  'ceilf',
#  'chdir',
#  'chmod',
#  'clearerr',
#  'clock_gettime',
#  'clone',
#  'close',
#  'closedir',
#  'compress2',
#  'compressBound',
#  'connect',
#  'cos',
#  'cosf',
#  'cosh',
#  'coshf',
#  'crc32',
#  'ctime',
#  'dl_iterate_phdr',
#  'dladdr',
#  'dlclose',
#  'dlerror',
#  'dlopen',
#  'dlsym',
#  'dup',
#  'dup2',
#  'el_end',
#  'el_get',
#  'el_gets',
#  'el_init',
#  'el_insertstr',
#  'el_line',
#  'el_push',
#  'el_set',
#  'environ',
#  'erf',
#  'erfc',
#  'erfcf',
#  'erff',
#  'execv',
#  'execve',
#  'execvp',
#  'exit',
#  'exp',
#  'exp2',
#  'exp2f',
#  'expf',
#  'expm1',
#  'expm1f',
#  'fabs',
#  'fchmod',
#  'fchown',
#  'fclose',
#  'fcntl',
#  'fdopen',
#  'feclearexcept',
#  'feof',
#  'ferror',
#  'fetestexcept',
#  'fflush',
#  'fgets',
#  'fileno',
#  'flock',
#  'floor',
#  'fmod',
#  'fmodf',
#  'fopen',
#  'fork',
#  'fprintf',
#  'fputc',
#  'fputs',
#  'fread',
#  'free',
#  'freeaddrinfo',
#  'frexp',
#  'fseek',
#  'fstat',
#  'fstat64',
#  'fstatfs',
#  'ftell',
#  'ftruncate',
#  'futimens',
#  'fwrite',
#  'gai_strerror',
#  'getaddrinfo',
#  'getauxval',
#  'getc',
#  'getcwd',
#  'getenv',
#  'gethostname',
#  'getloadavg',
#  'getpagesize',
#  'getpid',
#  'getppid',
#  'getpwnam_r',
#  'getpwuid_r',
#  'getrlimit',
#  'getrusage',
#  'getsid',
#  'gettimeofday',
#  'getuid',
#  'gmtime',
#  'gmtime_r',
#  'history',
#  'history_end',
#  'history_init',
#  'ioctl',
#  'isalnum',
#  'isalpha',
#  'isatty',
#  'isdigit',
#  'isprint',
#  'isspace',
#  'kill',
#  'ldexp',
#  'ldiv',
#  'link',
#  'listen',
#  'llround',
#  'localtime',
#  'localtime_r',
#  'log',
#  'log10',
#  'log10f',
#  'log1p',
#  'log1pf',
#  'log2',
#  'log2f',
#  'logb',
#  'logf',
#  'longjmp',
#  'lround',
#  'lseek',
#  'lstat',
#  'lstat64',
#  'mallinfo2',
#  'malloc',
#  'memchr',
#  'memcmp',
#  'memcpy',
#  'memmove',
#  'memset',
#  'mkdir',
#  'mknod',
#  'mkstemp',
#  'mmap',
#  'modf',
#  'mprotect',
#  'msync',
#  'munmap',
#  'nextafter',
#  'open',
#  'opendir',
#  'perror',
#  'pipe',
#  'poll',
#  'posix_madvise',
#  'posix_spawn',
#  'posix_spawn_file_actions_adddup2',
#  'posix_spawn_file_actions_addopen',
#  'posix_spawn_file_actions_destroy',
#  'posix_spawn_file_actions_init',
#  'pow',
#  'powf',
#  'pread',
#  'printf',
#  'pthread_attr_destroy',
#  'pthread_attr_init',
#  'pthread_attr_setstacksize',
#  'pthread_cond_broadcast',
#  'pthread_cond_clockwait',
#  'pthread_cond_destroy',
#  'pthread_cond_init',
#  'pthread_cond_wait',
#  'pthread_create',
#  'pthread_detach',
#  'pthread_getaffinity_np',
#  'pthread_getname_np',
#  'pthread_getspecific',
#  'pthread_join',
#  'pthread_key_create',
#  'pthread_key_delete',
#  'pthread_mutex_destroy',
#  'pthread_mutex_init',
#  'pthread_mutex_lock',
#  'pthread_mutex_unlock',
#  'pthread_self',
#  'pthread_setaffinity_np',
#  'pthread_setname_np',
#  'pthread_setschedparam',
#  'pthread_setspecific',
#  'pthread_sigmask',
#  'ptrace',
#  'putchar',
#  'puts',
#  'qsort',
#  'raise',
#  'rand',
#  'read',
#  'readdir',
#  'readlink',
#  'realloc',
#  'realpath',
#  'recvmsg',
#  'regcomp',
#  'regerror',
#  'regexec',
#  'regfree',
#  'remove',
#  'rename',
#  'rint',
#  'round',
#  'roundf',
#  'sched_getaffinity',
#  'sched_setaffinity',
#  'sendmsg',
#  'setenv',
#  'setrlimit',
#  'setsid',
#  'setsockopt',
#  'shm_open',
#  'shm_unlink',
#  'sigaction',
#  'sigaddset',
#  'sigaltstack',
#  'sigemptyset',
#  'sigfillset',
#  'sigprocmask',
#  'sin',
#  'sinf',
#  'sinh',
#  'sinhf',
#  'snprintf',
#  'socket',
#  'socketpair',
#  'sprintf',
#  'sqrt',
#  'sqrtf',
#  'srand',
#  'stat',
#  'stat64',
#  'statfs',
#  'stderr',
#  'stdin',
#  'stdout',
#  'strcasecmp',
#  'strcat',
#  'strchr',
#  'strcmp',
#  'strcpy',
#  'strcspn',
#  'strdup',
#  'strerror',
#  'strerror_r',
#  'strftime',
#  'strlen',
#  'strncat',
#  'strncmp',
#  'strncpy',
#  'strnlen',
#  'strpbrk',
#  'strrchr',
#  'strsignal',
#  'strspn',
#  'strstr',
#  'strtod',
#  'strtof',
#  'strtok',
#  'strtok_r',
#  'symlink',
#  'syscall',
#  'sysconf',
#  'tan',
#  'tanf',
#  'tanh',
#  'tanhf',
#  'time',
#  'tolower',
#  'trunc',
#  'truncf',
#  'umask',
#  'uname',
#  'uncompress',
#  'unlink',
#  'unsetenv',
#  'usleep',
#  'vfprintf',
#  'vsnprintf',
#  'wait',
#  'wait4',
#  'waitpid',
#  'wcscasecmp',
#  'wcscmp',
#  'wcslen',
#  'wcsstr',
#  'wmemchr',
#  'wmemcmp',
#  'write']

# %%
sorted(
    u_symbol
    for u_symbol in u_symbols_to_o_files
    if u_symbol in t_symbols_to_o_files
    and len(t_symbols_to_o_files.get(u_symbol, [])) > 1
)
# Out:
# ['ExitOnErr',
#  'LLVMFuzzerInitialize',
#  'LLVMFuzzerTestOneInput',
#  '_Z19registerMyExtensionRN4mlir15DialectRegistryE',
#  '_ZN3toy4dumpERNS_9ModuleASTE',
#  '_ZN3toy7mlirGenERN4mlir11MLIRContextERNS_9ModuleASTE',
#  '_ZN4mlir3toy10ConstantOp6createERNS_9OpBuilderENS_8LocationENS_4TypeENS_17DenseElementsAttrE',
#  '_ZN4mlir3toy10ConstantOp6createERNS_9OpBuilderENS_8LocationENS_9TypeRangeENS_10ValueRangeERKNS0_6detail28ConstantOpGenericAdaptorBase10PropertiesEN4llvm8ArrayRefINS_14NamedAttributeEEE',
#  '_ZN4mlir3toy10ConstantOp6createERNS_9OpBuilderENS_8LocationEd',
#  '_ZN4mlir3toy10ConstantOp8getValueEv',
#  '_ZN4mlir3toy10ToyDialectC1EPNS_11MLIRContextE',
#  '_ZN4mlir3toy11TransposeOp27getCanonicalizationPatternsERNS_17RewritePatternSetEPNS_11MLIRContextE',
#  '_ZN4mlir3toy11TransposeOp6createERNS_9OpBuilderENS_8LocationENS_5ValueE',
#  '_ZN4mlir3toy13GenericCallOp6createERNS_9OpBuilderENS_8LocationEN4llvm9StringRefENS5_8ArrayRefINS_5ValueEEE',
#  '_ZN4mlir3toy21createLowerToLLVMPassEv',
#  '_ZN4mlir3toy23createLowerToAffinePassEv',
#  '_ZN4mlir3toy24createShapeInferencePassEv',
#  '_ZN4mlir3toy5AddOp6createERNS_9OpBuilderENS_8LocationENS_5ValueES5_',
#  '_ZN4mlir3toy5MulOp6createERNS_9OpBuilderENS_8LocationENS_5ValueES5_',
#  '_ZN4mlir3toy6FuncOp15getFunctionTypeEv',
#  '_ZN4mlir3toy6FuncOp6createERNS_9OpBuilderENS_8LocationEN4llvm9StringRefENS_12FunctionTypeENS5_8ArrayRefINS_14NamedAttributeEEE',
#  '_ZN4mlir3toy6detail23AddOpGenericAdaptorBaseC2ENS0_5AddOpE',
#  '_ZN4mlir3toy6detail23MulOpGenericAdaptorBaseC2ENS0_5MulOpE',
#  '_ZN4mlir3toy6detail24FuncOpGenericAdaptorBaseC2ENS0_6FuncOpE',
#  '_ZN4mlir3toy6detail25PrintOpGenericAdaptorBaseC2ENS0_7PrintOpE',
#  '_ZN4mlir3toy6detail26ReturnOpGenericAdaptorBaseC2ENS0_8ReturnOpE',
#  '_ZN4mlir3toy6detail28ConstantOpGenericAdaptorBaseC2ENS0_10ConstantOpE',
#  '_ZN4mlir3toy6detail29TransposeOpGenericAdaptorBaseC2ENS0_11TransposeOpE',
#  '_ZN4mlir3toy7PrintOp6createERNS_9OpBuilderENS_8LocationENS_5ValueE',
#  '_ZN4mlir3toy8ReturnOp6createERNS_9OpBuilderENS_8LocationE',
#  '_ZN4mlir3toy8ReturnOp6createERNS_9OpBuilderENS_8LocationENS_10ValueRangeE',
#  '_ZN4mlir3toy9ReshapeOp27getCanonicalizationPatternsERNS_17RewritePatternSetEPNS_11MLIRContextE',
#  '_ZN4mlir3toy9ReshapeOp6createERNS_9OpBuilderENS_8LocationENS_4TypeENS_5ValueE',
#  '_ZN4mlir3toy9ReshapeOp6createERNS_9OpBuilderENS_8LocationENS_9TypeRangeENS_10ValueRangeERKNS_15EmptyPropertiesEN4llvm8ArrayRefINS_14NamedAttributeEEE',
#  '_ZN4mlir6detail14TypeIDResolverINS_3toy10ConstantOpEvE2idE',
#  '_ZN4mlir6detail14TypeIDResolverINS_3toy10ToyDialectEvE2idE',
#  '_ZN4mlir6detail14TypeIDResolverINS_3toy11TransposeOpEvE2idE',
#  '_ZN4mlir6detail14TypeIDResolverINS_3toy5AddOpEvE2idE',
#  '_ZN4mlir6detail14TypeIDResolverINS_3toy5MulOpEvE2idE',
#  '_ZN4mlir6detail14TypeIDResolverINS_3toy6FuncOpEvE2idE',
#  '_ZN4mlir6detail14TypeIDResolverINS_3toy7PrintOpEvE2idE',
#  '_ZN4mlir6detail14TypeIDResolverINS_3toy8ReturnOpEvE2idE',
#  '_ZN4mlir6detail14TypeIDResolverINS_3toy9ReshapeOpEvE2idE',
#  '_ZTISt12length_error',
#  '_ZTISt20bad_array_new_length',
#  'llvmFuzzerInitialize']

# %% [markdown]
# ## Constructing the Object File Dependency Graph
#
# A directed graph is created: nodes are `.o` files, and edges go from a file needing a symbol to the file that defines it. This graph captures direct symbol-based build dependencies between object files (not including external libraries).

# %%
dependency_graph = nx.DiGraph()

for u_symbol, u_symbol_o_files in u_symbols_to_o_files.items():
    if u_symbol in t_symbols_to_o_files:
        t_symbol_o_files = t_symbols_to_o_files[u_symbol]
        if len(t_symbol_o_files) == 1:
            t_symbol_o_file = t_symbol_o_files[0]
            for u_symbol_o_file in u_symbol_o_files:
                dependency_graph.add_edge(u_symbol_o_file, t_symbol_o_file)

# %%
len(dependency_graph.nodes)
# Out:
# 4317

# %%
len(dependency_graph.edges)
# Out:
# 80265

# %%
circt_opt_cpp_o_dependencies = nx.descendants(
    dependency_graph,
    'circt/tools/circt-opt/circt-opt.cpp.o'
)

# %%
len(circt_opt_cpp_o_dependencies)
# Out:
# 850

# %%
implemented = set()
unimplemented = set()

for symbol_type, symbols in symbols_in_o_files[
    'circt/tools/circt-opt/circt-opt.cpp.o'
].items():
    if symbol_type.isupper() and symbol_type != 'U':
        for symbol in symbols:
            implemented.add(symbol)
    elif symbol_type == 'U':
        for symbol in symbols:
            unimplemented.add(symbol)

for o_file in circt_opt_cpp_o_dependencies:
    for symbol_type, symbols in symbols_in_o_files[
        o_file
    ].items():
        if symbol_type.isupper() and symbol_type != 'U':
            for symbol in symbols:
                implemented.add(symbol)
        elif symbol_type == 'U':
            for symbol in symbols:
                unimplemented.add(symbol)

unimplemented -= implemented

# %%
len(unimplemented)
# Out:
# 390

# %%
sorted(unimplemented)
# Out:
# ['ZSTD_CCtx_setParameter',
#  'ZSTD_compress2',
#  'ZSTD_compressBound',
#  'ZSTD_createCCtx',
#  'ZSTD_decompress',
#  'ZSTD_freeCCtx',
#  'ZSTD_getErrorName',
#  'ZSTD_isError',
#  '_Exit',
#  '_Unwind_Backtrace',
#  '_Unwind_GetIP',
#  '_Unwind_Resume',
#  '_ZNKSt3__110error_code7messageEv',
#  '_ZNKSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE4findEcm',
#  '_ZNKSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE7compareEmmPKcm',
#  '_ZNKSt3__114error_category10equivalentERKNS_10error_codeEi',
#  '_ZNKSt3__114error_category10equivalentEiRKNS_15error_conditionE',
#  '_ZNKSt3__114error_category23default_error_conditionEi',
#  '_ZNKSt3__119__shared_weak_count13__get_deleterERKSt9type_info',
#  '_ZNKSt3__123__match_any_but_newlineIcE6__execERNS_7__stateIcEE',
#  '_ZNKSt3__14__fs10filesystem4path10__filenameEv',
#  '_ZNKSt3__14__fs10filesystem4path11__extensionEv',
#  '_ZNKSt3__14__fs10filesystem4path13__parent_pathEv',
#  '_ZNKSt3__16locale4nameEv',
#  '_ZNKSt3__16locale9use_facetERNS0_2idE',
#  '_ZNSt11logic_errorC2EPKc',
#  '_ZNSt12length_errorD1Ev',
#  '_ZNSt12out_of_rangeD1Ev',
#  '_ZNSt13exception_ptrD1Ev',
#  '_ZNSt19bad_optional_accessD1Ev',
#  '_ZNSt20bad_array_new_lengthC1Ev',
#  '_ZNSt20bad_array_new_lengthD1Ev',
#  '_ZNSt3__111__call_onceERVmPvPFvS2_E',
#  '_ZNSt3__111regex_errorC1ENS_15regex_constants10error_typeE',
#  '_ZNSt3__111regex_errorD1Ev',
#  '_ZNSt3__111this_thread9sleep_forERKNS_6chrono8durationIxNS_5ratioILl1ELl1000000000EEEEE',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE5eraseEmm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6__initEPKcm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6__initEmc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6appendEPKc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6appendEPKcm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6assignEPKc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6assignEPKcm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6insertENS_11__wrap_iterIPKcEEc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6insertEmPKc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6insertEmPKcm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE6resizeEmc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE7replaceEmmPKcm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE7reserveEm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE9__grow_byEmmmmmm',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEE9push_backEc',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEC1ERKS5_',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEC1ERKS5_mmRKS4_',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEED1Ev',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEED2Ev',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEaSERKS5_',
#  '_ZNSt3__112basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEaSEc',
#  '_ZNSt3__112basic_stringIwNS_11char_traitsIwEENS_9allocatorIwEEE6resizeEmw',
#  '_ZNSt3__112placeholders2_1E',
#  '_ZNSt3__113basic_filebufIcNS_11char_traitsIcEEE4openEPKcj',
#  '_ZNSt3__113basic_filebufIcNS_11char_traitsIcEEE5closeEv',
#  '_ZNSt3__113basic_filebufIcNS_11char_traitsIcEEEC1Ev',
#  '_ZNSt3__113basic_filebufIcNS_11char_traitsIcEEED1Ev',
#  '_ZNSt3__113basic_istreamIcNS_11char_traitsIcEEE6sentryC1ERS3_b',
#  '_ZNSt3__113basic_istreamIcNS_11char_traitsIcEEED2Ev',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEE5writeEPKcl',
#  '_ZNSt3__113basic_ostreamIcNS_11char_traitsIcEEED2Ev',
#  '_ZNSt3__113random_deviceC2ERKNS_12basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEE',
#  '_ZNSt3__113random_deviceD1Ev',
#  '_ZNSt3__113random_deviceclEv',
#  '_ZNSt3__113shared_futureIvED1Ev',
#  '_ZNSt3__114__shared_countD2Ev',
#  '_ZNSt3__114error_categoryD2Ev',
#  '_ZNSt3__115__get_classnameEPKcb',
#  '_ZNSt3__115__thread_structC1Ev',
#  '_ZNSt3__115__thread_structD1Ev',
#  '_ZNSt3__115recursive_mutex4lockEv',
#  '_ZNSt3__115recursive_mutex6unlockEv',
#  '_ZNSt3__115recursive_mutexC1Ev',
#  '_ZNSt3__115recursive_mutexD1Ev',
#  '_ZNSt3__115system_categoryEv',
#  '_ZNSt3__116generic_categoryEv',
#  '_ZNSt3__117__assoc_sub_state12__make_readyEv',
#  '_ZNSt3__117__assoc_sub_state13set_exceptionESt13exception_ptr',
#  '_ZNSt3__117__assoc_sub_state16__on_zero_sharedEv',
#  '_ZNSt3__117__assoc_sub_state4waitEv',
#  '_ZNSt3__117__assoc_sub_state9set_valueEv',
#  '_ZNSt3__117bad_function_callD1Ev',
#  '_ZNSt3__118condition_variable10notify_allEv',
#  '_ZNSt3__118condition_variable10notify_oneEv',
#  '_ZNSt3__118condition_variable4waitERNS_11unique_lockINS_5mutexEEE',
#  '_ZNSt3__118condition_variableD1Ev',
#  '_ZNSt3__119__shared_mutex_base11lock_sharedEv',
#  '_ZNSt3__119__shared_mutex_base13unlock_sharedEv',
#  '_ZNSt3__119__shared_mutex_base4lockEv',
#  '_ZNSt3__119__shared_mutex_base6unlockEv',
#  '_ZNSt3__119__shared_mutex_baseC1Ev',
#  '_ZNSt3__119__shared_weak_count14__release_weakEv',
#  '_ZNSt3__119__shared_weak_count4lockEv',
#  '_ZNSt3__119__shared_weak_countD2Ev',
#  '_ZNSt3__119__thread_local_dataEv',
#  '_ZNSt3__120__get_collation_nameEPKc',
#  '_ZNSt3__120__throw_system_errorEiPKc',
#  '_ZNSt3__122__libcpp_verbose_abortEPKcz',
#  '_ZNSt3__14stofERKNS_12basic_stringIcNS_11char_traitsIcEENS_9allocatorIcEEEEPm',
#  '_ZNSt3__15ctypeIcE2idE',
#  '_ZNSt3__15mutex4lockEv',
#  '_ZNSt3__15mutex6unlockEv',
#  '_ZNSt3__16chrono12steady_clock3nowEv',
#  '_ZNSt3__16chrono12system_clock11from_time_tEl',
#  '_ZNSt3__16chrono12system_clock3nowEv',
#  '_ZNSt3__16chrono12system_clock9to_time_tERKNS0_10time_pointIS1_NS0_8durationIxNS_5ratioILl1ELl1000000EEEEEEE',
#  '_ZNSt3__16futureIvEC1EPNS_17__assoc_sub_stateE',
#  '_ZNSt3__16futureIvED1Ev',
#  '_ZNSt3__16localeC1ERKS0_',
#  '_ZNSt3__16localeC1Ev',
#  '_ZNSt3__16localeD1Ev',
#  '_ZNSt3__16thread20hardware_concurrencyEv',
#  '_ZNSt3__16thread4joinEv',
#  '_ZNSt3__16thread6detachEv',
#  '_ZNSt3__16threadD1Ev',
#  '_ZNSt3__17collateIcE2idE',
#  '_ZNSt3__17promiseIvE10get_futureEv',
#  '_ZNSt3__17promiseIvE9set_valueEv',
#  '_ZNSt3__17promiseIvEC1Ev',
#  '_ZNSt3__17promiseIvED1Ev',
#  '_ZNSt3__18ios_base4initEPv',
#  '_ZNSt3__18ios_base5clearEj',
#  '_ZNSt3__19basic_iosIcNS_11char_traitsIcEEED2Ev',
#  '_ZNSt3__19to_stringEd',
#  '_ZNSt3__19to_stringEf',
#  '_ZNSt3__19to_stringEi',
#  '_ZNSt3__19to_stringEj',
#  '_ZNSt3__19to_stringEl',
#  '_ZNSt3__19to_stringEm',
#  '_ZNSt3__1plIcNS_11char_traitsIcEENS_9allocatorIcEEEENS_12basic_stringIT_T0_T1_EEPKS6_RKS9_',
#  '_ZNSt9exceptionD2Ev',
#  '_ZSt15set_new_handlerPFvvE',
#  '_ZSt17current_exceptionv',
#  '_ZSt7nothrow',
#  '_ZSt9terminatev',
#  '_ZTTNSt3__114basic_ifstreamIcNS_11char_traitsIcEEEE',
#  '_ZTTNSt3__114basic_ofstreamIcNS_11char_traitsIcEEEE',
#  '_ZTVN10__cxxabiv117__class_type_infoE',
#  '_ZTVN10__cxxabiv120__si_class_type_infoE',
#  '_ZTVNSt3__114__shared_countE',
#  '_ZTVNSt3__114basic_ifstreamIcNS_11char_traitsIcEEEE',
#  '_ZTVNSt3__114basic_ofstreamIcNS_11char_traitsIcEEEE',
#  '_ZTVNSt3__117__assoc_sub_stateE',
#  '_ZTVNSt3__117bad_function_callE',
#  '_ZTVNSt3__119__shared_weak_countE',
#  '_ZTVNSt3__18ios_baseE',
#  '_ZTVNSt3__19basic_iosIcNS_11char_traitsIcEEEE',
#  '_ZTVSt12length_error',
#  '_ZTVSt12out_of_range',
#  '_ZTVSt18bad_variant_access',
#  '_ZTVSt19bad_optional_access',
#  '_ZTVSt9exception',
#  '_ZdaPv',
#  '_ZdaPvm',
#  '_ZdlPv',
#  '_ZdlPvSt11align_val_t',
#  '_ZdlPvm',
#  '_ZdlPvmSt11align_val_t',
#  '_Znam',
#  '_Znwm',
#  '_ZnwmRKSt9nothrow_t',
#  '_ZnwmSt11align_val_t',
#  '_ZnwmSt11align_val_tRKSt9nothrow_t',
#  '__assert_fail',
#  '__ctype_b_loc',
#  '__ctype_tolower_loc',
#  '__ctype_toupper_loc',
#  '__cxa_allocate_exception',
#  '__cxa_atexit',
#  '__cxa_begin_catch',
#  '__cxa_end_catch',
#  '__cxa_free_exception',
#  '__cxa_guard_abort',
#  '__cxa_guard_acquire',
#  '__cxa_guard_release',
#  '__cxa_pure_virtual',
#  '__cxa_rethrow',
#  '__cxa_thread_atexit',
#  '__cxa_throw',
#  '__dso_handle',
#  '__errno_location',
#  '__gxx_personality_v0',
#  '__isoc23_strtol',
#  '__isoc23_strtoll',
#  '__isoc23_strtoull',
#  '__sched_cpucount',
#  '__tls_get_addr',
#  '_exit',
#  '_setjmp',
#  'abort',
#  'access',
#  'acos',
#  'acosf',
#  'acosh',
#  'acoshf',
#  'alarm',
#  'arc4random',
#  'asin',
#  'asinf',
#  'asinh',
#  'asinhf',
#  'atan',
#  'atan2',
#  'atan2f',
#  'atanf',
#  'atanh',
#  'atanhf',
#  'backtrace',
#  'bcmp',
#  'calloc',
#  'ceil',
#  'chdir',
#  'chmod',
#  'close',
#  'closedir',
#  'compress2',
#  'compressBound',
#  'cos',
#  'cosf',
#  'cosh',
#  'coshf',
#  'dl_iterate_phdr',
#  'dladdr',
#  'dlclose',
#  'dlerror',
#  'dlopen',
#  'dlsym',
#  'dup',
#  'dup2',
#  'environ',
#  'erf',
#  'erfc',
#  'erfcf',
#  'erff',
#  'execv',
#  'execve',
#  'exit',
#  'exp',
#  'exp2',
#  'exp2f',
#  'expf',
#  'expm1',
#  'expm1f',
#  'fchmod',
#  'fchown',
#  'fcntl',
#  'fileno',
#  'floor',
#  'fork',
#  'fprintf',
#  'fputc',
#  'fputs',
#  'free',
#  'fstat',
#  'fstatfs',
#  'ftruncate',
#  'futimens',
#  'fwrite',
#  'getauxval',
#  'getcwd',
#  'getenv',
#  'getpid',
#  'getpwnam_r',
#  'getpwuid_r',
#  'getrlimit',
#  'getrusage',
#  'getuid',
#  'ioctl',
#  'isalpha',
#  'isatty',
#  'isdigit',
#  'kill',
#  'link',
#  'log',
#  'log10',
#  'log10f',
#  'log1p',
#  'log1pf',
#  'log2',
#  'log2f',
#  'logf',
#  'longjmp',
#  'lseek',
#  'lstat',
#  'mallinfo2',
#  'malloc',
#  'memchr',
#  'memcmp',
#  'memcpy',
#  'memmove',
#  'memset',
#  'mkdir',
#  'mmap',
#  'modf',
#  'msync',
#  'munmap',
#  'open',
#  'opendir',
#  'posix_madvise',
#  'posix_spawn',
#  'posix_spawn_file_actions_adddup2',
#  'posix_spawn_file_actions_addopen',
#  'posix_spawn_file_actions_destroy',
#  'posix_spawn_file_actions_init',
#  'pow',
#  'powf',
#  'pread',
#  'printf',
#  'pthread_attr_destroy',
#  'pthread_attr_init',
#  'pthread_attr_setstacksize',
#  'pthread_create',
#  'pthread_detach',
#  'pthread_getname_np',
#  'pthread_join',
#  'pthread_self',
#  'pthread_setname_np',
#  'pthread_setschedparam',
#  'pthread_setspecific',
#  'pthread_sigmask',
#  'putchar',
#  'qsort',
#  'raise',
#  'read',
#  'readdir',
#  'readlink',
#  'realloc',
#  'realpath',
#  'remove',
#  'rename',
#  'rint',
#  'round',
#  'roundf',
#  'sched_getaffinity',
#  'setrlimit',
#  'setsid',
#  'sigaction',
#  'sigaddset',
#  'sigaltstack',
#  'sigemptyset',
#  'sigfillset',
#  'sigprocmask',
#  'sin',
#  'sinf',
#  'sinh',
#  'sinhf',
#  'snprintf',
#  'sqrt',
#  'sqrtf',
#  'stat',
#  'statfs',
#  'stderr',
#  'stdin',
#  'stdout',
#  'strchr',
#  'strcmp',
#  'strdup',
#  'strerror_r',
#  'strlen',
#  'strncmp',
#  'strncpy',
#  'strrchr',
#  'strsignal',
#  'strtod',
#  'strtof',
#  'strtok_r',
#  'symlink',
#  'syscall',
#  'sysconf',
#  'tan',
#  'tanf',
#  'tanh',
#  'tanhf',
#  'trunc',
#  'truncf',
#  'umask',
#  'uncompress',
#  'unlink',
#  'usleep',
#  'vsnprintf',
#  'wait',
#  'wait4',
#  'wmemchr',
#  'write']

# %%
print("$AR", "rcs", "circt_opt_cpp_o_dependencies.a", " ".join(circt_opt_cpp_o_dependencies))
# Out:
# $AR rcs circt_opt_cpp_o_dependencies.a llvm-project/build/tools/mlir/lib/Dialect/Utils/CMakeFiles/obj.MLIRDialectUtils.dir/VerificationUtils.cpp.o circt/lib/Dialect/FIRRTL/FIRRTLUtils.cpp.o circt/lib/Conversion/SimToSV/SimToSV.cpp.o llvm-project/build/tools/mlir/lib/Dialect/IRDL/CMakeFiles/obj.MLIRIRDL.dir/IRDLSymbols.cpp.o circt/lib/Support/SymCache.cpp.o circt/lib/Dialect/LTL/LTLDialect.cpp.o llvm-project/build/tools/mlir/lib/Conversion/ArithToLLVM/CMakeFiles/obj.MLIRArithToLLVM.dir/ArithToLLVM.cpp.o llvm-project/build/tools/mlir/lib/Analysis/Presburger/CMakeFiles/obj.MLIRPresburger.dir/PresburgerSpace.cpp.o llvm-project/build/lib/Demangle/CMakeFiles/LLVMDemangle.dir/MicrosoftDemangleNodes.cpp.o circt/lib/Support/LoweringOptions.cpp.o llvm-project/build/tools/mlir/lib/Analysis/Presburger/CMakeFiles/obj.MLIRPresburger.dir/Utils.cpp.o llvm-project/build/lib/Support/CMakeFiles/LLVMSupport.dir/Threading.cpp.o circt/lib/Dialect/FIRRTL/Transforms/LowerMemory.cpp.o llvm-project/build/lib/IR/CMakeFiles/LLVMCore.dir/DebugInfo.cpp.o circt/lib/Dialect/FIRRTL/Transforms/InferResets.cpp.o llvm-project/build/tools/mlir/lib/Dialect/Complex/IR/CMakeFiles/obj.MLIRComplexDialect.dir/ComplexOps.cpp.o llvm-project/build/tools/mlir/lib/Conversion/ReconcileUnrealizedCasts/CMakeFiles/obj.MLIRReconcileUnrealizedCasts.dir/ReconcileUnrealizedCasts.cpp.o llvm-project/build/tools/mlir/lib/Transforms/Utils/CMakeFiles/obj.MLIRTransformUtils.dir/WalkPatternRewriteDriver.cpp.o llvm-project/build/tools/mlir/lib/Support/CMakeFiles/obj.MLIRSupport.dir/InterfaceSupport.cpp.o llvm-project/build/lib/Support/CMakeFiles/LLVMSupport.dir/ConvertUTF.cpp.o circt/lib/Tools/circt-lec/ConstructLEC.cpp.o circt/lib/Dialect/MSFT/MSFTDialect.cpp.o llvm-project/build/tools/mlir/lib/IR/CMakeFiles/obj.MLIRIR.dir/Diagnostics.cpp.o circt/lib/Dialect/FIRRTL/Transforms/EliminateWires.cpp.o circt/lib/Dialect/RTG/IR/RTGISAAssemblyAttrInterfaces.cpp.o circt/lib/Transforms/StripDebugInfoWithPred.cpp.o circt/lib/Dialect/RTG/Transforms/LinearScanRegisterAllocationPass.cpp.o llvm-project/build/tools/mlir/lib/Debug/CMakeFiles/obj.MLIRDebug.dir/DebugCounter.cpp.o circt/lib/Dialect/FIRRTL/Transforms/LayerSink.cpp.o llvm-project/build/tools/mlir/lib/Dialect/SMT/IR/CMakeFiles/obj.MLIRSMT.dir/SMTAttributes.cpp.o circt/lib/Dialect/Verif/Transforms/StripContracts.cpp.o circt/lib/Dialect/FIRRTL/FIRRTLInstanceImplementation.cpp.o circt/lib/Conversion/ExportVerilog/ExportVerilog.cpp.o circt/lib/Dialect/SV/Transforms/HWEliminateInOutPorts.cpp.o circt/lib/Conversion/SMTToZ3LLVM/LowerSMTToZ3LLVM.cpp.o circt/lib/Dialect/RTG/Transforms/ElaborationPass.cpp.o circt/lib/Transforms/MemoryBanking.cpp.o llvm-project/build/tools/mlir/lib/Transforms/CMakeFiles/obj.MLIRTransforms.dir/SCCP.cpp.o circt/lib/Dialect/Datapath/DatapathDialect.cpp.o circt/lib/Dialect/Debug/DebugOps.cpp.o llvm-project/build/tools/mlir/lib/Interfaces/CMakeFiles/obj.MLIRLoopLikeInterface.dir/LoopLikeInterface.cpp.o circt/lib/Dialect/OM/Transforms/FreezePaths.cpp.o circt/lib/Dialect/Calyx/Transforms/ClkResetInsertion.cpp.o llvm-project/build/tools/mlir/lib/Bytecode/CMakeFiles/obj.MLIRBytecodeOpInterface.dir/BytecodeOpInterface.cpp.o llvm-project/build/tools/mlir/lib/Bytecode/Writer/CMakeFiles/obj.MLIRBytecodeWriter.dir/IRNumbering.cpp.o circt/lib/Dialect/Synth/Transforms/StructuralHash.cpp.o circt/lib/Dialect/SSP/Transforms/Print.cpp.o circt/lib/Dialect/Seq/SeqOps.cpp.o llvm-project/build/lib/IR/CMakeFiles/LLVMCore.dir/ConstantRangeList.cpp.o circt/lib/Dialect/Kanagawa/Transforms/KanagawaEliminateRedundantOps.cpp.o circt/lib/Dialect/FIRRTL/Transforms/ResolvePaths.cpp.o llvm-project/build/lib/TargetParser/CMakeFiles/LLVMTargetParser.dir/Triple.cpp.o circt/lib/Scheduling/SimplexSchedulers.cpp.o circt/lib/Dialect/Calyx/Transforms/GICM.cpp.o circt/lib/Dialect/Handshake/HandshakeOps.cpp.o circt/lib/Analysis/DependenceAnalysis.cpp.o llvm-project/build/tools/mlir/lib/Interfaces/CMakeFiles/obj.MLIRValueBoundsOpInterface.dir/ValueBoundsOpInterface.c ...

# %% [markdown]
# ```
# $CXX circt/tools/circt-opt/circt-opt.cpp.o circt_opt_cpp_o_dependencies.a -o circt-opt -lz -lzstd
# ```
